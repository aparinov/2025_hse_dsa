# %% [markdown]
# # Генератор синтетических данных заявок студентов на проекты
#
# Этот notebook генерирует синтетические данные для заявок студентов на проекты с использованием метода гауссовых кластеров.
#
# ## Особенности:
# - **Проекты**: Загружаются из реальной таблицы (880 проектов из колонки "Наименование ЭПП")
# - **Метод генерации**: Гауссовы кластеры с настраиваемым коэффициентом сжатия α
# - **Признаки студентов**: 40 признаков = 40 предметов факультета компьютерных наук
# - **Изученные предметы**: Каждый студент изучал 15 из 40 предметов (для остальных оценка = 0)
# - **Связь кластеров и оценок**: Оценки студентов генерируются на основе признаков кластеров
# - **Популярность проектов**: Распределение по закону Zipf (первые проекты более популярны)
# - **Оценки студентов**: 10-балльная шкала (5-10) с преобладанием высоких баллов
# - **Временной диапазон**: 1-14 дней после открытия проектов

# %%
import numpy as np
import pandas as pd
from datetime import datetime, timedelta
import random
from typing import List, Dict, Tuple
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)
random.seed(42)

# %% [markdown]
# ## 1. Определение базовых параметров и списков

# %%
# Пробный список предметов
SUBJECTS = [
    'Алгоритмы и структуры данных',
    'Дискретная математика',
    'Математический анализ',
    'Линейная алгебра',
    'Теория вероятностей',
    'Математическая статистика',
    'Программирование на Python',
    'Программирование на Java',
    'Программирование на C++',
    'Web-разработка',
    'Базы данных',
    'Операционные системы',
    'Компьютерные сети',
    'Архитектура компьютера',
    'Теория автоматов',
    'Теория вычислений',
    'Машинное обучение',
    'Глубокое обучение',
    'Компьютерное зрение',
    'Обработка естественного языка',
    'Искусственный интеллект',
    'Data Science',
    'Анализ данных',
    'Информационная безопасность',
    'Криптография',
    'Распределенные системы',
    'Облачные вычисления',
    'Мобильная разработка',
    'Разработка игр',
    'Компиляторы',
    'Функциональное программирование',
    'Объектно-ориентированное программирование',
    'Проектирование ПО',
    'Тестирование ПО',
    'DevOps',
    'Agile методологии',
    'Графика и визуализация',
    'Параллельное программирование',
    'Квантовые вычисления',
    'Биоинформатика'
]

# Загрузка реальных проектов из таблицы
projects_df = pd.read_csv('projects_list.csv', encoding='utf-8-sig')

# Создаем список проектов с популярностью
# Популярность генерируем по закону Zipf (первые проекты более популярны)
n_projects = len(projects_df)
zipf_ranks = np.arange(1, n_projects + 1)
popularities = 1.0 / zipf_ranks
popularities = popularities / popularities.sum()  # Нормализуем

PROJECTS = []
for idx, row in projects_df.iterrows():
    PROJECTS.append({
        'id': row['id'],
        'name': row['name'],
        'popularity': popularities[idx]
    })

print(f"Загружено {len(PROJECTS)} проектов")
print(f"\nПримеры проектов:")
for i in range(min(10, len(PROJECTS))):
    print(f"  {PROJECTS[i]['id']}. {PROJECTS[i]['name']} (популярность: {PROJECTS[i]['popularity']:.4f})")

# Дата старта проектов
PROJECT_START_DATE = datetime(2024, 9, 1)
# Out:
# Загружено 880 проектов
#
# Примеры проектов:
#   1. Исследование приоритетов и механизмов реализации отраслевых (секторальных) политик в избранных странах БРИКС (членах и кандидатах), во взаимосвязи с повесткой международных доноров (популярность: 0.1359)
#   2. Антрополе - научно-популярный видео-подкаст о необычных социальных феноменах (популярность: 0.0680)
#   3. Разработка, создание и ведение сайта, посвященного истории арабских студентов, выпускников художественных ВУЗов СССР (1950-е - 1991 г.) (популярность: 0.0453)
#   4. Перевод с английского языка коллективной монографии «Пятьдесят ключевых мыслителей в криминологии» (науч. ред.: Кейт Хейворд, Шадд Маруна, Джейн Муни, изд-во Routledge, 2010. — 352 с.). (популярность: 0.0340)
#   5. Сеть военно-политических союзов в Евразии: база данных (популярность: 0.0272)
#   6. Дизайн учебных материалов (презентаций) (популярность: 0.0227)
#   7. ОРЗ Изучении практик многоязычного обучения в школах Республики Бурятия (популярность: 0.0194)
#   8. Привязанность к месту и психосоциальное здоровье: метаанализ (популярность: 0.0170)
#   9. Подготовка управленческих решений на корпоративном уровне (популярность: 0.0151)
#   10. Дизайн лонгрида "Корея в Москве и Санкт-Петербурге" (популярность: 0.0136)

# %% [markdown]
# ## 2. Генерация кластеров методом гауссовых распределений

# %%
def generate_gaussian_clusters(n_objects: int, n_features: int, n_clusters: int, 
                               alpha: float, min_cluster_size: int = 10) -> Tuple[np.ndarray, np.ndarray]:
    """
    Генерирует многомерные данные с гауссовыми кластерами.
    
    Parameters:
    -----------
    n_objects : int
        Количество объектов (студентов)
    n_features : int
        Количество признаков
    n_clusters : int
        Количество кластеров
    alpha : float
        Коэффициент сжатия (0 < alpha < 1). Чем больше - тем больше перемешивание
    min_cluster_size : int
        Минимальный размер кластера
    
    Returns:
    --------
    X : np.ndarray
        Матрица данных размером (n_objects, n_features)
    labels : np.ndarray
        Метки кластеров для каждого объекта
    """
    # Шаг 1: Распределение объектов по кластерам
    cluster_sizes = np.random.multinomial(n_objects - n_clusters * min_cluster_size, 
                                          [1/n_clusters] * n_clusters)
    cluster_sizes += min_cluster_size
    
    # Шаг 2: Генерация центров кластеров
    # Диапазон для координат центров зависит от alpha
    range_val = 1.0 / alpha if alpha > 0 else 1.0
    centers = np.random.uniform(-range_val, range_val, size=(n_clusters, n_features))
    
    # Шаг 3: Генерация точек для каждого кластера
    X = []
    labels = []
    
    for cluster_id in range(n_clusters):
        cluster_center = centers[cluster_id]
        cluster_size = cluster_sizes[cluster_id]
        
        # Генерация стандартных отклонений для каждого признака
        std_devs = np.random.uniform(0.1, 0.5, size=n_features)
        
        # Генерация точек кластера
        cluster_points = np.random.normal(
            loc=cluster_center,
            scale=std_devs,
            size=(cluster_size, n_features)
        )
        
        X.append(cluster_points)
        labels.extend([cluster_id] * cluster_size)
    
    # Шаг 4: Объединение всех кластеров
    X = np.vstack(X)
    labels = np.array(labels)
    
    # Перемешивание данных
    indices = np.random.permutation(len(X))
    X = X[indices]
    labels = labels[indices]
    
    return X, labels

# %% [markdown]
# ## 3. Генерация профилей студентов

# %%
def generate_student_grades_from_features(student_features: np.ndarray, 
                                          subjects: List[str],
                                          n_subjects_per_student: int = 15) -> Dict[int, Dict[str, int]]:
    """
    Генерирует оценки студентов на основе признаков из гауссовых кластеров.
    
    Parameters:
    -----------
    student_features : np.ndarray
        Матрица признаков студентов (n_students x n_features=40)
        Каждый признак соответствует предмету из списка SUBJECTS
    subjects : List[str]
        Список всех предметов (40 предметов)
    n_subjects_per_student : int
        Количество предметов, которые изучал каждый студент (по умолчанию 15)
    
    Returns:
    --------
    Dict[int, Dict[str, int]]
        Словарь {student_id: {subject: grade}}
        Для неизученных предметов оценка = 0
    """
    n_students = len(student_features)
    n_features = len(subjects)  # Количество признаков = количество предметов
    student_grades = {}
    
    # Нормализуем признаки в диапазон [0, 1] для каждого признака отдельно
    # Используем min-max нормализацию по столбцам
    features_min = student_features.min(axis=0)
    features_max = student_features.max(axis=0)
    features_range = features_max - features_min
    features_range[features_range == 0] = 1  # Избегаем деления на 0
    
    normalized_features = (student_features - features_min) / features_range
    
    for student_id in range(n_students):
        grades = {}
        
        # Выбираем n_subjects_per_student предметов, которые изучал студент
        # Выбираем предметы с наибольшими значениями признаков (студент лучше в них)
        student_feature_values = normalized_features[student_id]
        
        # Выбираем n_subjects_per_student предметов, которые изучал студент
        # Используем вероятностное распределение на основе значений признаков
        # Возводим в степень для усиления различий
        probabilities = np.power(student_feature_values, 2)
        probabilities = probabilities / probabilities.sum()
        
        # Выбираем n_subjects_per_student предметов по вероятностям
        studied_subject_indices = np.random.choice(
            n_features, 
            size=n_subjects_per_student, 
            replace=False, 
            p=probabilities
        )
        
        # Для всех 40 предметов генерируем оценки
        for subject_idx, subject in enumerate(subjects):
            if subject_idx in studied_subject_indices:
                # Студент изучал этот предмет - преобразуем признак в оценку
                feature_value = normalized_features[student_id, subject_idx]
                
                # Преобразуем [0, 1] в оценку [5, 10]
                # Добавляем немного случайности для разнообразия
                noise = np.random.uniform(-0.1, 0.1)
                adjusted_value = feature_value + noise
                adjusted_value = np.clip(adjusted_value, 0, 1)
                
                # Масштабируем в [5, 10]
                grade = 5 + adjusted_value * 5
                grade = int(np.round(grade))
                grade = np.clip(grade, 5, 10)
                
                grades[subject] = grade
            else:
                # Студент не изучал этот предмет - оценка 0
                grades[subject] = 0
        
        student_grades[student_id] = grades
    
    return student_grades

# %% [markdown]
# ## 4. Генерация заявок

# %%
def select_project_by_popularity(projects: List[Dict]) -> int:
    """
    Выбирает проект с учетом его популярности.
    
    Parameters:
    -----------
    projects : List[Dict]
        Список проектов с информацией о популярности
    
    Returns:
    --------
    int
        ID выбранного проекта
    """
    project_ids = [p['id'] for p in projects]
    popularities = [p['popularity'] for p in projects]
    
    # Нормализуем популярности в вероятности
    total = sum(popularities)
    probabilities = [p / total for p in popularities]
    
    return np.random.choice(project_ids, p=probabilities)


def generate_application_timestamp(project_start: datetime, 
                                   min_days: int = 1, 
                                   max_days: int = 14) -> datetime:
    """
    Генерирует время создания заявки.
    
    Parameters:
    -----------
    project_start : datetime
        Дата начала проекта
    min_days : int
        Минимальное количество дней после начала
    max_days : int
        Максимальное количество дней после начала
    
    Returns:
    --------
    datetime
        Временная метка заявки
    """
    days_offset = random.randint(min_days, max_days)
    hours_offset = random.randint(0, 23)
    minutes_offset = random.randint(0, 59)
    
    return project_start + timedelta(
        days=days_offset,
        hours=hours_offset,
        minutes=minutes_offset
    )


def generate_applications(n_students: int, 
                         student_grades: Dict[int, Dict[str, int]],
                         projects: List[Dict],
                         project_start_date: datetime) -> pd.DataFrame:
    """
    Генерирует заявки студентов на проекты.
    
    Parameters:
    -----------
    n_students : int
        Количество студентов
    student_grades : Dict[int, Dict[str, int]]
        Словарь оценок студентов
    projects : List[Dict]
        Список проектов
    project_start_date : datetime
        Дата начала проектов
    
    Returns:
    --------
    pd.DataFrame
        DataFrame с заявками
    """
    applications = []
    application_id = 0
    
    for student_id in range(n_students):
        # Каждый студент подает от 1 до 3 заявок
        n_applications = random.randint(1, 3)
        
        # Выбираем проекты без повторений для одного студента
        selected_projects = []
        for _ in range(n_applications):
            project_id = select_project_by_popularity(projects)
            # Пытаемся избежать дубликатов, но если не получается за 10 попыток - берем
            attempts = 0
            while project_id in selected_projects and attempts < 10:
                project_id = select_project_by_popularity(projects)
                attempts += 1
            selected_projects.append(project_id)
        
        for project_id in selected_projects:
            # Получаем доступные предметы студента
            available_subjects = list(student_grades[student_id].keys())
            # Получаем все предметы студента с ненулевыми оценками (изученные предметы)
            all_subjects = student_grades[student_id]
            available_subjects = [subj for subj, grade in all_subjects.items() if grade > 0]
            
            # Выбираем 3 предмета для демонстрации (только с ненулевыми оценками)
            n_subjects_to_show = min(3, len(available_subjects))
            subjects_to_show = random.sample(available_subjects, n_subjects_to_show)
            
            # Получаем оценки (они неизменны для студента)
            grades = [student_grades[student_id][subj] for subj in subjects_to_show]
            
            # Генерируем время подачи заявки
            timestamp = generate_application_timestamp(project_start_date)
            
            # Создаем заявку
            application = {
                'application_id': application_id,
                'student_id': student_id,
                'project_id': project_id,
                'timestamp': timestamp,
                'subject_1': subjects_to_show[0] if len(subjects_to_show) > 0 else None,
                'grade_1': grades[0] if len(grades) > 0 else None,
                'subject_2': subjects_to_show[1] if len(subjects_to_show) > 1 else None,
                'grade_2': grades[1] if len(grades) > 1 else None,
                'subject_3': subjects_to_show[2] if len(subjects_to_show) > 2 else None,
                'grade_3': grades[2] if len(grades) > 2 else None,
            }
            
            applications.append(application)
            application_id += 1
    
    return pd.DataFrame(applications)

# %% [markdown]
# ## 5. Основная функция генерации данных

# %%
def generate_synthetic_data(n_students: int, 
                           alpha: float = 0.3,
                           n_clusters: int = 5,
                           save_to_file: bool = True) -> Tuple[pd.DataFrame, Dict]:
    """
    Генерирует полный набор синтетических данных.
    
    Parameters:
    -----------
    n_students : int
        Количество студентов
    alpha : float
        Коэффициент сжатия для кластеров (0 < alpha < 1)
    n_clusters : int
        Количество кластеров студентов
    save_to_file : bool
        Сохранять ли результаты в файл
    
    Returns:
    --------
    Tuple[pd.DataFrame, Dict]
        DataFrame с заявками и словарь с метаданными
    """
    print(f"Генерация данных для {n_students} студентов...")
    
    # Генерируем профили студентов с использованием гауссовых кластеров
    # Каждый признак = предмет (всего 40 предметов из SUBJECTS)
    print("  - Создание кластеров студентов...")
    n_features = len(SUBJECTS)  # 40 признаков = 40 предметов
    student_features, cluster_labels = generate_gaussian_clusters(
        n_objects=n_students,
        n_features=n_features,
        n_clusters=n_clusters,
        alpha=alpha
    )
    
    # Генерируем оценки студентов на основе признаков кластеров
    print("  - Генерация оценок студентов на основе кластеров...")
    student_grades = generate_student_grades_from_features(
        student_features=student_features,
        subjects=SUBJECTS,
        n_subjects_per_student=15  # Каждый студент изучал 15 из 40 предметов
    )
    
    # Генерируем заявки
    print("  - Генерация заявок...")
    applications_df = generate_applications(
        n_students=n_students,
        student_grades=student_grades,
        projects=PROJECTS,
        project_start_date=PROJECT_START_DATE
    )
    
    # Метаданные
    metadata = {
        'n_students': n_students,
        'n_applications': len(applications_df),
        'n_projects': len(PROJECTS),
        'alpha': alpha,
        'n_clusters': n_clusters,
        'cluster_labels': cluster_labels,
        'student_features': student_features
    }
    
    # Сохранение в файл
    if save_to_file:
        filename = f'applications_{n_students}_students.csv'
        applications_df.to_csv(filename, index=False, encoding='utf-8')
        print(f"  - Данные сохранены в {filename}")
    
    print(f"✓ Сгенерировано {len(applications_df)} заявок от {n_students} студентов")
    
    return applications_df, metadata

# %% [markdown]
# ## 6. Визуализация и анализ данных

# %%
def analyze_and_visualize(applications_df: pd.DataFrame, metadata: Dict):
    """
    Анализирует и визуализирует сгенерированные данные.
    """
    print("\n=== Анализ данных ===")
    print(f"Всего заявок: {len(applications_df)}")
    print(f"Всего студентов: {metadata['n_students']}")
    print(f"Среднее количество заявок на студента: {len(applications_df) / metadata['n_students']:.2f}")
    
    # Распределение по проектам
    print("\nРаспределение заявок по проектам:")
    project_counts = applications_df['project_id'].value_counts().sort_index()
    for project_id, count in project_counts.items():
        project_name = next(p['name'] for p in PROJECTS if p['id'] == project_id)
        print(f"  Проект {project_id} ({project_name}): {count} заявок")
    
    # Распределение оценок
    print("\nРаспределение оценок:")
    all_grades = []
    for col in ['grade_1', 'grade_2', 'grade_3']:
        all_grades.extend(applications_df[col].dropna().values)
    all_grades = np.array(all_grades)
    print(f"  Средняя оценка: {np.mean(all_grades):.2f}")
    print(f"  Медиана: {np.median(all_grades):.2f}")
    print(f"  Мин/Макс: {np.min(all_grades)}/{np.max(all_grades)}")
    
    # Визуализация
    fig, axes = plt.subplots(2, 2, figsize=(15, 12))
    
    # 1. Распределение заявок по проектам
    project_counts.plot(kind='bar', ax=axes[0, 0], color='skyblue')
    axes[0, 0].set_title('Распределение заявок по проектам')
    axes[0, 0].set_xlabel('ID проекта')
    axes[0, 0].set_ylabel('Количество заявок')
    axes[0, 0].grid(axis='y', alpha=0.3)
    
    # 2. Распределение оценок
    axes[0, 1].hist(all_grades, bins=range(5, 12), alpha=0.7, color='green', edgecolor='black')
    axes[0, 1].set_title('Распределение оценок')
    axes[0, 1].set_xlabel('Оценка')
    axes[0, 1].set_ylabel('Частота')
    axes[0, 1].grid(axis='y', alpha=0.3)
    
    # 3. Временное распределение заявок
    applications_df['timestamp'] = pd.to_datetime(applications_df['timestamp'])
    applications_df['days_since_start'] = (applications_df['timestamp'] - PROJECT_START_DATE).dt.days
    axes[1, 0].hist(applications_df['days_since_start'], bins=30, alpha=0.7, color='orange', edgecolor='black')
    axes[1, 0].set_title('Распределение заявок по времени')
    axes[1, 0].set_xlabel('Дней с начала проектов')
    axes[1, 0].set_ylabel('Количество заявок')
    axes[1, 0].grid(axis='y', alpha=0.3)
    
    # 4. Кластеры студентов (первые 2 главные компоненты)
    from sklearn.decomposition import PCA
    pca = PCA(n_components=2)
    student_features_2d = pca.fit_transform(metadata['student_features'])
    scatter = axes[1, 1].scatter(student_features_2d[:, 0], 
                                  student_features_2d[:, 1],
                                  c=metadata['cluster_labels'],
                                  cmap='viridis',
                                  alpha=0.6)
    axes[1, 1].set_title('Кластеры студентов (PCA)')
    axes[1, 1].set_xlabel('Первая главная компонента')
    axes[1, 1].set_ylabel('Вторая главная компонента')
    plt.colorbar(scatter, ax=axes[1, 1], label='Кластер')
    
    plt.tight_layout()
    plt.savefig(f'analysis_{metadata["n_students"]}_students.png', dpi=300, bbox_inches='tight')
    print(f"\n✓ Визуализация сохранена в analysis_{metadata['n_students']}_students.png")
    plt.show()

# %% [markdown]
# ## 7. Генерация всех наборов данных

# %%
# Список размеров датасетов
dataset_sizes = [500, 1000, 3000, 7000]

# Генерация всех наборов данных
results = {}

for n_students in dataset_sizes:
    print(f"\n{'='*60}")
    print(f"Генерация датасета для {n_students} студентов")
    print(f"{'='*60}")
    
    applications_df, metadata = generate_synthetic_data(
        n_students=n_students,
        alpha=0.3,  # Коэффициент сжатия - можно варьировать для разной степени перемешивания
        n_clusters=5,  # Количество типов студентов
        save_to_file=True
    )
    
    results[n_students] = (applications_df, metadata)
    
    # Анализ и визуализация
    analyze_and_visualize(applications_df, metadata)

print("\n" + "="*60)
print("✓ Все датасеты успешно сгенерированы!")
print("="*60)
# Out:
# ============================================================
# Генерация датасета для 500 студентов
# ============================================================
# Генерация данных для 500 студентов...
#   - Создание кластеров студентов...
#   - Генерация оценок студентов на основе кластеров...
#   - Генерация заявок...
#   - Данные сохранены в applications_500_students.csv
# ✓ Сгенерировано 989 заявок от 500 студентов
#
# === Анализ данных ===
# Всего заявок: 989
# Всего студентов: 500
# Среднее количество заявок на студента: 1.98
#
# Распределение заявок по проектам:
#   Проект 1 (Исследование приоритетов и механизмов реализации отраслевых (секторальных) политик в избранных странах БРИКС (членах и кандидатах), во взаимосвязи с повесткой международных доноров): 131 заявок
#   Проект 2 (Антрополе - научно-популярный видео-подкаст о необычных социальных феноменах): 65 заявок
#   Проект 3 (Разработка, создание и ведение сайта, посвященного истории арабских студентов, выпускников художественных ВУЗов СССР (1950-е - 1991 г.)): 47 заявок
#   Проект 4 (Перевод с английского языка коллективной монографии «Пятьдесят ключевых мыслителей в криминологии» (науч. ред.: Кейт Хейворд, Шадд Маруна, Джейн Муни, изд-во Routledge, 2010. — 352 с.).): 34 заявок
#   Проект 5 (Сеть военно-политических союзов в Евразии: база данных): 33 заявок
#   Проект 6 (Дизайн учебных материалов (презентаций)): 24 заявок
#   Проект 7 (ОРЗ Изучении практик многоязычного обучения в школах Республики Бурятия): 18 заявок
#   Проект 8 (Привязанность к месту и психосоциальное здоровье: метаанализ): 14 заявок
#   Проект 9 (Подготовка управленческих решений на корпоративном уровне): 16 заявок
#   Проект 10 (Дизайн лонгрида "Корея в Москве и Санкт-Петербурге"): 17 заявок
#   Проект 11 (Копирайтер): 13 заявок
#   Проект 12 (Переводы пьес театра Кабуки с классического японского языка): 17 заявок
#   Проект 13 (Японская библиотека ИКВИА: организация и каталогизация): 5 заявок
#   Проект 14 (Ведение социальных сетей проекта про предпринимательство и стартапы): 10 заявок
#   Проект 15 (Корпус «Полевые материалы российско-вьетнамских лингвистических экспедиций»: создание лингвистического компонента): 10 заявок
#   Проект 16 (Правовые аспекты обучения моделей искусственного интеллекта: анализ зарубежного правового регулирования, судебной практики и саморегулирования): 14 заявок
#   Проект 17 (Работа со сложным гримом: шаржи и карикатуры, национально-исторический грим): 10 заявок
#   Проект 18 (Флипбук на JS): 8 заявок
#   Проект 19 (Создание электронной базы данных архива художника (на примере архивов В.Г. Вейсберга и Б.К. Касаткина). Часть2.): 11 заявок
#   Проект 20 (Исторические сферы влияния: создание базы данных): 8 заявок
#   Проект 21 (Ежемесячный мониторинг мировой экономики и геополитических рисков «GlobBaro HSE» (сентябрь-март 2026)): 8 заявок
#   Проект 22 (Просветительский проект «Голос Востока»): 7 заявок
#   Проект 23 (Анализ, описание и обработка электронных документов кадровых практик Всероссийского конкурса "Лучшие кадровые практики и инициативы в системе государственного и муниципального управления"): 5 заявок
#   Проект 24 (Перевод современной персидской художественной и мемуарной прозы): 4 заявок
#   Проект 25 (Лексика эфиопской Книги Юбилеев: составление глоссария ко второй главе): 5 заявок
#   Проект 26 (Развитие и продвижение студенческой научно-популярной организации «Восточный причал»): 5 заявок
#   Проект 27 (Перевод современной хиндиязычной прозы): 4 заявок
#   Проект 28 (Запуск регулярного подкаста НИУ ВШЭ о странах Азии): 7 заявок
#   Проект 30 (Классический японский язык: чтение, перевод, анализ грамматики древних текстов): 1 заявок
#   Проект 31 (Студенческий клуб "Говорим об Эфиопии"): 5 заявок
#   Проект 32 (История турецкой литературы и фольклора): 6 заявок
#   Проект 33 (Медиапродвижение магистерской программы «Мусульманские миры в России (история и культура)»): 11 заявок
#   Проект 34 (Арабский рассказ и современная литературная теория): 7 заявок
#   Проект 35 (Египетский и сирийский диалекты арабского языка: создание учебного пособия): 3 заявок
#   Проект 36 (Проект по развитию центра культурной идентичности при факультете креативных индустрий ВШЭ): 1 заявок
#   Проект 37 (Правовая азбука для НКО Центр равных возможностей "Вверх" (проведение мастер-классов и разработка методических материалов), новый набор (третий год реализации проекта)): 4 заявок
#   Проект 38 (Евразийская интеграция: правовое измерение): 3 заявок
#   Проект 39 (Медиаосвещение спортивных событий ВШЭ. Развитие единого медиа канала по спорту в университете): 4 заявок
#   Проект 40 (Взгляд изнутри ВШБ НИУ ВШЭ): 4 заявок
#   Проект 41 (Учебный ассистент по дисциплине "Бизнес-анализ в цепях поставок"): 4 заявок
#   Проект 42 (Социальная память о философии и философах в документальном советском и перестроечном кино и современных медиа): 3 заявок
#   Проект 43 (Везувианская зона как метамузей Древнего Рима: апробация редизайна курса и подготовки учебного пособия): 4 заявок
#   Проект 44 (Меж- & транскультурная коммуникация и межкультурная компетенция/ Inter-&Transkulturalität und Interkulturelle Kompetenz (онлайн)): 3 заявок
#   Проект 45 (Проектирование хранилища данных для приюта для бездомных животных): 2 заявок
#   Проект 46 (Стартап: Цифровой маркетплейс недвижимости "Домдом"): 2 заявок
#   Проект 47 (Музыкальная культура России и Европы: Дон-Жуан в музыкальной культуре (опера, балет, мюзикл)): 2 заявок
#   Проект 49 (Разработка Телеграм-бота по подбору образовательных программ): 3 заявок
#   Проект 51 (Разработка периодического издания в сфере гуманитарных наук 2025-2026 уч.г. (10-й этап). Журнал молодых ученых «Метаморфозис». Том 10.): 1 заявок
#   Проект 52 (Юридическая клиника факультета права НИУ ВШЭ): 3 заявок
#   Проект 53 (Чтение древнееврейской прозы): 4 заявок
#   Проект 54 (Разговорный английский клуб НИУ ВШЭ СПб Talking Crows): 2 заявок
#   Проект 56 (Визовое сопровождение иностранных студентов): 2 заявок
#   Проект 57 (Особенности ведения бизнеса в разных странах 2025-2026): 1 заявок
#   Проект 58 (Разработка и развертывание стратегии международной компании 2025-2026): 4 заявок
#   Проект 59 (Управление проектами и процессами в международном бизнесе 2025-2026): 1 заявок
#   Проект 60 (Развитие Платформы соинвестирования ключевых компетенций (ПСКК) во взаимодействии с Минпромторгом России, Госкорпорациями "Ростех" и "Росатом" 2025-2026): 3 заявок
#   Проект 61 (Эволюция политической и деловой элиты в современной России): 1 заявок
#   Проект 62 (Визуальные объекты как исторический источник): 1 заявок
#   Проект 63 (Кинопроба. Медиа акселератор для НКО): 2 заявок
#   Проект 64 (Медиакоманда ЭКСТРА: для ОП «Журналистика» и «Медиакоммуникации»): 3 заявок
#   Проект 65 (Организационное сопровождение курса и педагогический дизайн его элементов): 3 заявок
#   Проект 66 (Межрегиональный научно-популярный фестиваль «Делай, что любишь!»): 1 заявок
#   Проект 67 (Волонтерство на XVI Международной конференции исследователей высшего образования (конференции ИВО)): 2 заявок
#   Проект 68 (Создание полноценного цифрового (или omnichannel) бизнес-проекта, готового к выходу на рынок): 4 заявок
#   Проект 69 (Ведение телеграм-канала центра российской истории и культуры при факультете креативных индустрий Высшей школы экономики): 2 заявок
#   Проект 70 (Проект по развитию центра российской истории и культуры при факультете креативных индустрий ВШЭ): 2 заявок
#   Проект 71 (Медиакоманда Центра Культур): 1 заявок
#   Проект 73 (Участие и создание креативных роликов на тему Ирана): 3 заявок
#   Проект 74 (Кейсбук: Социальное предпринимательство в России): 1 заявок
#   Проект 75 (Китайский клуб НИУ ВШЭ 2025/2026): 2 заявок
#   Проект 76 (Организация Школы юного востоковеда 2025/2026): 3 заявок
#   Проект 77 (Количественный анализ международной торговли): 2 заявок
#   Проект 78 (Международный мониторинг ответственного бизнеса): 2 заявок
#   Проект 79 (Съемки историй-секвенций): 2 заявок
#   Проект 81 (Съемки мини-секвенций для альманаха): 1 заявок
#   Проект 82 (Организация мероприятий культурно-просветительской направленности (клуб Наследие.ВШЭ)): 2 заявок
#   Проект 83 (Обработка материалов экспедиции "Общественная самоорганизация и система муниципального управления: теория взаимовлияния, опыт Челябинской области, пути повышения эффективности конструктивного взаимодействия"): 1 заявок
#   Проект 84 (Научные Кураторы НИУ ВШЭ: вовлечение иностранных студентов в научную деятельность): 1 заявок
#   Проект 86 (Ведение телеграм-канала об академическом развитии и помощи в написании работ «Писать нельзя откладывать»): 2 заявок
#   Проект 87 (Школа будущего международника: десятый сезон (2025/2026)): 1 заявок
#   Проект 89 (Внешняя политика России в отношении стран Латинской Америки в XXI веке): 3 заявок
#   Проект 92 (Перспектива замены менеджеров среднего звена искусственным интеллектом): 3 заявок
#   Проект 94 (Современные тренды государственного управления и их роль в противодействии коррупции): 1 заявок
#   Проект 95 (Антикоррупционные требования в частном секторе и защита компаний от коррупционных и правовых рисков: опыт зарубежных юрисдикций): 3 заявок
#   Проект 96 (Предупреждение коррупции в правоохранительных органах: международная стандарты и практика): 2 заявок
#   Проект 97 (Коррупционные практики в банкротных процедурах): 1 заявок
#   Проект 98 (Специализированные антикоррупционные органы – международные подходы и практика): 1 заявок
#   Проект 101 (Создание и редактирование контента для студенческого интернет-портала Hitmedia.su): 1 заявок
#   Проект 102 (Ближневосточный клуб НИУ ВШЭ: платформа для изучения региона и развития академического и карьерного потенциала студентов-ближневосточников 2025/26): 1 заявок
#   Проект 103 (Разработка и редактирование информационного бюллетеня «СРЕДА» №9 (октябрь 2025 г.) и №10 (ноябрь 2025 г.)): 2 заявок
#   Проект 104 (Ведение авторского телеграмм-канала "В поисках равновесия"): 1 заявок
#   Проект 105 (Освещение игрового и тренировочного процесса Сборных команд НИУ ВШЭ (мужских и женских) по футболу, футзалу, пляжному футболу в медиа ресурсах. Репортажи, трансляции, статьи, аналитика. Осень 2025): 1 заявок
#   Проект 106 (Организация, проведение и освещение Кубка по футзалу среди студентов НИУ ВШЭ - 2025.): 2 заявок
#   Проект 109 (Японский клуб «Мусуби» НИУ ВШЭ): 1 заявок
#   Проект 112 (Практикум Совета молодых дипломатов): 3 заявок
#   Проект 113 (Антикоррупционные расследования в коммерческом секторе): 2 заявок
#   Проект 114 (Создание каталога нереализованных литературных журналов и газет XIX века): 1 заявок
#   Проект 115 (Религиозный ландшафт города: пост-секулярная история религиозных общин Санкт-Петербурга): 3 заявок
#   Проект 116 (Баскетбол в НИУ ВШЭ): 1 заявок
#   Проект 117 (Образованность как фактор коррупционных рисков: анализ англоязычных публикаций): 1 заявок
#   Проект 119 (SMM-сопровождение телеграм-СМИ о моде "кисс"): 1 заявок
#   Проект 120 (Продвижение в социальных сетях деятельности научно-учебной лаборатории исследований современного Ирана): 1 заявок
#   Проект 121 (Корпус русскоязычных газет XIX века. 2025-2026 учебный год): 1 заявок
#   Проект 122 (Сравнение современных проблем Восточной Азии через призму градиентов социально-экономического развития): 2 заявок
#   Проект 123 (Подготовка документов для поступления в магистратуру для выпускников бакалавриата Школы востоковедения НИУ ВШЭ): 1 заявок
#   Проект 124 (Консультация историка для киноклуба): 1 заявок
#   Проект 127 (Редакция социальных сетей и сайта Института медиа НИУ ВШЭ (первое полугодие 2025-2026)): 3 заявок
#   Проект 128 (Помощь в организации и проведении 14й Международной научной конференции «Общественная самоорганизация, государственное управление и местное самоуправление в России и за рубежом»): 3 заявок
#   Проект 129 (Первый выход в поле: этнографические методы в социальной антропологии): 1 заявок
#   Проект 131 (Языки и тексты буддизма: перевод и исследование "Гимна в сто пятьдесят строф" Матричеты. 2025/26 учебный год): 2 заявок
#   Проект 132 (Анализ полевых данных и этика исследования): 1 заявок
#   Проект 133 (Социальная теория и этнография: 2025/2026): 1 заявок
#   Проект 135 (Языковое сопровождение 14-й Международной научной конференции «Общественная самоорганизация, государственное управление и местное самоуправление в России и за рубежом»): 2 заявок
#   Проект 137 (Школьное математическое образование первой четверти XXI века: аналитические материалы): 1 заявок
#   Проект 138 (Данные РМЭЗ в исследовании перехода от учебы к работе): 2 заявок
#   Проект 139 (Мониторинг макроэкономической и финансовой ситуации стран БРИКС): 4 заявок
#   Проект 140 (Японский театр: погружение в культуру через игру): 2 заявок
#   Проект 142 (Телеграм канал Департамента социологии НИУ ВШЭ СПб): 1 заявок
#   Проект 143 (Менторская поддержка участников Всероссийского кейс-чемпионата школьников по экономике и предпринимательству): 2 заявок
#   Проект 144 (Культурно-исторический квест по Москве «HSE RUN»): 1 заявок
#   Проект 145 («Креативная Внеучебка» — главное студенческое медиа о внеучебной жизни ФКИ НИУ ВШЭ): 2 заявок
#   Проект 146 (Ассистенты Центра кинопроизводства Института кино, 2025-2026 учебный год): 1 заявок
#   Проект 148 (Организация митап-форумов в рамках Межкампусного проекта «Точка Сборки»): 1 заявок
#   Проект 152 (Психофизиологическое исследование: Как мотивация влияет на рабочую память?): 2 заявок
#   Проект 153 (Транскрибирование и редактура видеозаписей лекций А. С. Немзера): 2 заявок
#   Проект 154 (Многоязычие иранских СМИ): 2 заявок
#   Проект 155 (Музеи Ирана): 1 заявок
#   Проект 156 (Разработка путеводителя по Москве для туристов из региона MENA (язык проекта — арабский)): 1 заявок
#   Проект 157 (Работа в проекте Школа предпринимательства: от трекеров и кураторов проектов до пиар-менеджеров и дизайнеров): 4 заявок
#   Проект 161 (Библиотека научно-образовательной секции исследований Ближнего Востока и Северной Африки Школы востоковедения («Ближневосточный кабинет»).): 2 заявок
#   Проект 162 (Подкаст об ответственном отношении к животным #НеЗвери. 4 сезон): 1 заявок
#   Проект 164 (Современное Искусство Ближнего Востока): 1 заявок
#   Проект 166 (Кураторы общежитии): 1 заявок
#   Проект 171 (Перевод ключевых экокритических статей): 1 заявок
#   Проект 172 (Апробация шкалы межпоколенного конфликта на рабочем месте на русскоязычной выборке): 1 заявок
#   Проект 178 (VII Международная конференция «Мировое большинство»): 1 заявок
#   Проект 179 (Онлайн-журнал "MindMasters"): 1 заявок
#   Проект 180 (Анализ и перспективы применения технологий искусственного интеллекта в деятельности оконной компании KARVI): 1 заявок
#   Проект 181 (Студенческое медиа Высшей школы бизнеса 2025-2026 уч. год): 1 заявок
#   Проект 183 (Россия и Организация исламского сотрудничества (ОИС): оценка современного состояния взаимодействия и перспектив развития): 2 заявок
#   Проект 185 (Открытая правовая школа (первое полугодие 2025-2026 уч. года)): 1 заявок
#   Проект 186 (Разработка контента для позиционирования ОП "История"): 1 заявок
#   Проект 188 (Продвижение в социальных сетях образовательной программы магистратуры «Современное востоковедение»): 3 заявок
#   Проект 189 (Истмейкерс (Творцы востока)): 1 заявок
#   Проект 191 (Векторы и контуры будущего мировой экономики, политики и общества: взгляд молодых исследователей): 2 заявок
#   Проект 193 (Развитие дайджеста по социальному предпринимательству): 2 заявок
#   Проект 195 (Politburg - подкаст о гражданском образовании): 1 заявок
#   Проект 196 (Киноклуб "XXI век" на канале Грибоедова): 2 заявок
#   Проект 203 (Энергосбережение в строительстве Японии (с 2025): эффекты, риски и возможности для российского бизнеса): 2 заявок
#   Проект 204 (Математические соревнования школьников 2025-26 уч год): 1 заявок
#   Проект 205 («Менторство в исследованиях по социологии» студенческий проект по сопровождению участников конкурса научно-исследовательских проектов «Высший пилотаж» 2025-2026): 1 заявок
#   Проект 206 (Проверка математических олимпиад 2026): 1 заявок
#   Проект 207 (Развитие научной платформы "Creative Writing Studies"): 2 заявок
#   Проект 208 (Разработка интерактивной карты православных храмов Москвы): 1 заявок
#   Проект 209 (Цифровые сервисы в сохранении и продвижении культурного наследия: цифровой образ Санкт-Петербурга): 2 заявок
#   Проект 216 (Организация Национальной олимпиады по анализу данных DANO): 1 заявок
#   Проект 217 (Официальная помощь развитию как инструмент внешней политики Японии): 1 заявок
#   Проект 218 (Медиакоманда Центра поддержки студенческих инициатив (ЦПСИ)): 1 заявок
#   Проект 221 (История Востока для «чайников»): 1 заявок
#   Проект 226 (Перевод фильма на арабский язык): 1 заявок
#   Проект 228 (Христианство северо-восточной Африки): 1 заявок
#   Проект 229 (Sprachbrücke - Языковой мост): 1 заявок
#   Проект 232 (Лингвистический кинопрактикум на турецком языке): 1 заявок
#   Проект 233 (Китайский клуб НИУ ВШЭ – Санкт-Петербург): 1 заявок
#   Проект 234 (Telegram-канал для изучающих китайский язык): 1 заявок
#   Проект 235 (Индийский клуб НИУ ВШЭ – Санкт-Петербург): 1 заявок
#   Проект 236 (Вьетнамский клуб): 2 заявок
#   Проект 239 (Корейский кино-клуб): 2 заявок
#   Проект 241 (Перевод японских комиксов манга и субтитров к японским видео): 1 заявок
#   Проект 242 (СНК «Клуб уголовного права»): 2 заявок
#   Проект 243 (Улучшение имиджа Санкт-Петербурга как туристического направления у японской аудитории): 1 заявок
#   Проект 252 (Наполнение стратегической базы данных экспертов Форсайт-центра ИСИЭЗ НИУ ВШЭ): 2 заявок
#   Проект 254 (Трансформация структуры экономики России и системы общественных ценностей в условиях геополитической турбулентности): 1 заявок
#   Проект 262 (Ведение социальных сетей кафедры международных отношений и политических процессов стран Азии и Африки): 2 заявок
#   Проект 263 (Разработка учебно-методических материалов для дисциплины «Начальный курс китайского языка»): 1 заявок
#   Проект 266 (Политический анализ стран Азии и Африки): 3 заявок
#   Проект 267 (Помощь детям из Азии и Ближнего Востока: волонтерская инициатива Российского Красного Креста): 1 заявок
#   Проект 268 («Тройка» Северо-Восточной Азии: состояние, проблемы и перспективы сотрудничества Китая, Японии и Южной Кореи.): 1 заявок
#   Проект 276 («Группы самопомощи в университете»): 1 заявок
#   Проект 277 (Евангелие от Марка: учебный комментарий (главы 9-12)): 1 заявок
#   Проект 279 (Учебные ассистенты 1-2 модули 2025-2026 академический год. За кредиты. Бакалавры Кёнхи): 2 заявок
#   Проект 280 (Ведение социальных сетей сообщества «Кураторы Вышки» для образовательных программ «Журналистика» и «Медиакоммуникации»): 1 заявок
#   Проект 284 (Первые годы издания журнала "Юность": редакционная политика и читательский спрос): 1 заявок
#   Проект 285 (Дискуссионный клуб на Арабском языке. Этап 2): 1 заявок
#   Проект 288 (Журналы "Советский Союз" (1930-1991) и "Советская женщина" (1945-1991): мягкая сила и медиа в создании международного имиджа СССР.): 1 заявок
#   Проект 292 (Стандарты и прецеденты адвокатской практики (адвокатская мастерская)): 1 заявок
#   Проект 293 (Арабский язык в медиасреде): 2 заявок
#   Проект 296 (Феномен коллективного Запада и перспективы трансатлантических отношений): 1 заявок
#   Проект 297 (Бизнес и предпринимательство в странах БРИКС+: исследование практического взаимодействия): 1 заявок
#   Проект 303 (Роль атомной энергетики и природного газа в создании конкурентных преимуществ для технологического сектора США и Китая): 3 заявок
#   Проект 306 (Японский язык для кросс-культурных исследований: этап 2): 2 заявок
#   Проект 307 (Международное уголовное правосудие – взгляд в будущее): 1 заявок
#   Проект 313 (ОРГСЕКТОР: Организация Модели ООН НИУ ВШЭ “HSEMUN-26”): 1 заявок
#   Проект 314 (Студенческий клуб кафедры ближневосточных и африканских исследований): 3 заявок
#   Проект 315 (КОМИТЕТЫ: Работа с комитетами Модели ООН НИУ ВШЭ «HSEMUN-26»): 1 заявок
#   Проект 316 (Разработка программы и организация медиаканикул «Путешествие по Вышке»): 1 заявок
#   Проект 319 (Влияние США, Турции, европейских и ближневосточных государств на энергетические отношения России и Китая со странами Центральной Азии.): 1 заявок
#   Проект 321 (Обновление каталога методических материалов для дисциплины "Основные подходы в психологическом консультировании"): 1 заявок
#   Проект 323 (Незападные традиции историографии и современная историческая наука в колониальных и постколониальных условиях): 2 заявок
#   Проект 324 (Встречи интервизионной группы в методе транзактного анализа): 1 заявок
#   Проект 327 (Японская каллиграфия: китайские источники и современные интерпретации): 1 заявок
#   Проект 328 (Книжный клуб): 1 заявок
#   Проект 329 (Редактирование книги по экспедиции "Приморье. Сохранить и переосмыслить"): 1 заявок
#   Проект 330 (Клуб изучения немецкого языка НИУ ВШЭ СПб для продолжающих Deutsch für Fortgeschrittene (B2-C1)): 1 заявок
#   Проект 332 (Перевод и субтитрирование китайских фильмов): 1 заявок
#   Проект 333 (Китайский киноклуб): 1 заявок
#   Проект 336 (Литературный фестиваль): 2 заявок
#   Проект 344 (Создание контента для медиа-канала «Продюсер в музыкальной индустрии»): 2 заявок
#   Проект 358 (Цифровая трансформация государственного управления в регионах России: визуализация данных): 1 заявок
#   Проект 361 (Медиевализм в русской литературе XIX-XX вв. (создание базы данных)): 2 заявок
#   Проект 371 (Закон как уникальный продукт: механизм подготовки и принятия в Государственной Думе Федерального Собрания Российской Федерации): 1 заявок
#   Проект 377 (Международный дискуссионный клуб кино): 3 заявок
#   Проект 385 (Инклюзивный клуб НИУ ВШЭ): 1 заявок
#   Проект 394 (Цифровой образовательный портфель управленца): 1 заявок
#   Проект 400 («Зимняя школа 2026:  «Чем выше, тем круче. Чем круче, тем трудней.  Чем трудней, тем интересней!»): 1 заявок
#   Проект 401 (История науки раннего Нового и Нового времени в вопросах и ответах): 1 заявок
#   Проект 406 (Международные подходы и модели подготовки кадров социально-гуманитарного профиля для традиционных и коммерческих космических программ): 1 заявок
#   Проект 420 (МЕДИАСЕКТОР Сопровождение Модели ООН НИУ ВШЭ “HSEMUN-26”: Дизайнеры): 1 заявок
#   Проект 425 (Тест): 1 заявок
#   Проект 432 (Студенческая медиагруппа факультета права): 1 заявок
#   Проект 436 (Российская Федерация и страны Европы: история отношений): 2 заявок
#   Проект 439 (Создание корпуса статей по выгоранию): 1 заявок
#   Проект 441 (Цифровой универсальный комментарий): 1 заявок
#   Проект 442 (Промысловая охота в современной России: второй сезон): 1 заявок
#   Проект 449 (Лаборатория исследовательских зинов 2025): 1 заявок
#   Проект 470 (Межкультурная коммуникация студентов России и Мексики): 1 заявок
#   Проект 471 (Российско-белорусские отношения (2022-2025)): 1 заявок
#   Проект 473 (Создание графического и визуального оформления для серии документальных видео и эдьютейнмент-постов о проектах ИСИЭЗ НИУ ВШЭ): 1 заявок
#   Проект 484 (Продвижение информационного, аналитического и развлекательного контента в социальных сетях и офлайн-пространстве для магистерской программы «Языковые технологии в бизнесе и образовании»): 1 заявок
#   Проект 488 (Создание мобильного приложения для изучения РЖЯ на основе модели классификации видео): 2 заявок
#   Проект 489 (Создание мультимедийного чат-бота в приложении Telegram с возможностью изучения хантыйского языка и фольклора): 1 заявок
#   Проект 500 (Разработка датасета для оценки безопасности диалоговых сервисов психологической поддержки с использованием БЯМ): 1 заявок
#   Проект 503 (Тест 1 + фамилии участников): 1 заявок
#   Проект 504 (Продвижение информационного, аналитического и развлекательного контента в социальных сетях и офлайн-пространстве для программы «Тексты, языки и цифровые инструменты»): 1 заявок
#   Проект 505 (Современные методы инвестиционного анализа): 1 заявок
#   Проект 507 (Мой ЭПП): 1 заявок
#   Проект 512 (Разработка системы классификации степени тяжести афазии на основе анализа речевых сигналов): 1 заявок
#   Проект 513 (Комплексное исследование международных климатических объединений): 2 заявок
#   Проект 514 (Гордеева, Соломенникова): 1 заявок
#   Проект 519 (Система автоматической оценки компетенций и подбора программ профессионального развития сотрудников ПАО "Северсталь"): 1 заявок
#   Проект 523 (Пайплайн для определения типа афазии с помощью LLM): 1 заявок
#   Проект 524 (GlossSystem: система выявления и перевода проектного диалекта команды): 1 заявок
#   Проект 528 (Your Intelligence Guard: чат-бот для выявления и анализа правовых коллизий и лакун в области интеллектуальной собственности. ): 1 заявок
#   Проект 530 (Sensory Studies: рецензии, обзоры и публикации): 1 заявок
#   Проект 532 (Производство документального кинопроекта): 1 заявок
#   Проект 544 (Введение канала, посвященного Российским городам): 1 заявок
#   Проект 551 (Создание арт-галереи современного искусства в Перми): 1 заявок
#   Проект 552 (Перевод с английского языка коллективной монографии «Пятьдесят ключевых мыслителей в криминологии» (науч. ред.: Кейт Хейворд, Шадд Маруна, Джейн Муни, изд-во Routledge, 2010. — 352 с.). Совместная, в соавторстве с двумя или тремя участниками проекта, подготовка и публикация учебного пособия, посвященного актуальным проблемам современной зарубежной криминологии.): 1 заявок
#   Проект 553 (Банкротство (Акулова, Контузорова) ): 2 заявок
#   Проект 557 (Винников, Бурлак: Цифровой навигатор прав и льгот студента ВШЭ): 1 заявок
#   Проект 565 (“LegalConnect: Интерактивная образовательная платформа для студентов-юристов” Гордеева, Соломенникова): 1 заявок
#   Проект 571 (Юридический журнал "Законъ" (Медведев, Плюснин)): 2 заявок
#   Проект 574 (Кино-история Прикамья-летний образовательный кинопроект ): 1 заявок
#   Проект 577 (Учебный ассистент по дисциплине Этика бизнеса): 1 заявок
#   Проект 580 (Разработка актуальных учебно-методических материалов по корейскому языку): 1 заявок
#   Проект 587 (Волонтеры на участие в Международной научно-практической конференции "Информационные технологии в сохранении и продвижении культурного наследия"): 1 заявок
#   Проект 588 (Создание медийной стратегии для маркетинга игр): 1 заявок
#   Проект 590 (Разработка рекомендаций по управлению налоговой нагрузкой компаний): 1 заявок
#   Проект 591 (Анализ влияния изменения налогового законодательства на эффективность деятельности компании): 1 заявок
#   Проект 595 (Кодекс закупок для публичных нужд): 1 заявок
#   Проект 601 (Управление региональной ценовой политикой в области электроэнергетики): 1 заявок
#   Проект 611 (Просветительский проект “Кружок внимательности ВШЭ” по популяризации и информированию студентов в сфере практик осознанности.): 1 заявок
#   Проект 614 (Аудиосериал "Трамвай №3" о старой и новой Москве): 1 заявок
#   Проект 616 (Трансформация архитектуры безопасности в Восточной Азии): 1 заявок
#   Проект 618 (Перспективные конфигурации Большого Средиземноморья): 1 заявок
#   Проект 625 (Стратегический консалтинг на мировых рынках): 1 заявок
#   Проект 631 (Сравнение результатов применения метрики прибыли с существующими метриками, учитывающими финансовый результат для оценки моделей скоринга.): 1 заявок
#   Проект 632 (Разработка лексических карточек на платформе Wordstool для курса “Английский язык для современной социокультурной повестки” магистерской программы “Иностранные языки и межкультурная коммуникация” Школы иностранных языков НИУ ВШЭ): 1 заявок
#   Проект 633 (Метаанализ теоретических концепций мышления учащихся основной школы (5-9 класс) в контексте цифровизации, искусственного интеллекта и нейрокогнитивных наук): 1 заявок
#   Проект 643 (Интеллектуальное планирование: внедрение CPM и диаграммы Ганта): 1 заявок
#   Проект 645 (Оценка стратегий цифрового маркетинга для понимания потребителей и роста бренда): 1 заявок
#   Проект 648 (Лингвистическое и организационное сопровождение деятельности департамента иностранных языков): 1 заявок
#   Проект 651 (Разработка коммуникационной стратегии нового издания "Июнь"): 1 заявок
#   Проект 657 (Переводчик интервью с русского на английский): 1 заявок
#   Проект 670 (Сбор и обработка данных о предсказуемости слов при чтении текста на родном и иностранном языке): 2 заявок
#   Проект 678 (Уважение человека труда: теория и реализация посредством права): 1 заявок
#   Проект 683 (Анализ эффективности работы партнеров и оптимизации кампаний на основе данных): 1 заявок
#   Проект 685 (Разработка инструмента на основе искусственного интеллекта для оценки регуляторных рисков): 1 заявок
#   Проект 705 (Разработка приложения для учёта студенческих организаций в НИУ ВШЭ - Пермь): 1 заявок
#   Проект 708 (Создание базы данных ошибок чтения слух у подростков): 1 заявок
#   Проект 712 (Создание типовых правовых документов деятельности ТОС): 1 заявок
#   Проект 718 (Запись серии подкастов о научно-популярном туризме): 1 заявок
#   Проект 728 (Топография публичных пространств "Второй культуры" Ленинграда 1970–80-х): 1 заявок
#   Проект 731 (Прикладные исследования современного фольклора): 3 заявок
#   Проект 747 (Древнееврейский язык: разработка учебных материалов): 1 заявок
#   Проект 757 (Экспертная сессия: "Turning Creativity into Business" 2026): 1 заявок
#   Проект 760 (Анализ курсов по цифровым инструментам и искусственному интеллекту в преподавании): 1 заявок
#   Проект 761 (Подготовка и проведение Восьмой международной конференции Модели ООН «Higher School of Economics International Model United Nations» – HSEIMUN 2026): 1 заявок
#   Проект 773 (Совершенствование механизмов государственной социальной поддержки студентов: опыт стран БРИКС): 1 заявок
#   Проект 774 (Формирование ценностного предложения работодателя (EVP) с использованием смешанных методов исследования 2 волна): 1 заявок
#   Проект 790 (Школьный буллинг как фактор подавления агентности: анализ механизмов и поиск противодействий): 1 заявок
#   Проект 792 (Влияние семейного контекста на формирование агентности у детей и подростков): 1 заявок
#   Проект 795 (Сон Журавля): 1 заявок
#   Проект 796 (Международные амбассадоры НИУ ВШЭ – Санкт-Петербург): 1 заявок
#   Проект 799 (Разработка учебного пособия "Сборник нормативно-правовых актов СССР"): 4 заявок
#   Проект 807 (Интерактивная карта цифровых решений системы публичных закупок с тренажером действий заказчиков и участников закупок): 1 заявок
#   Проект 818 (Подготовка Рейтинга инновационной привлекательности мировых городов HSE GCII 2026): 1 заявок
#   Проект 830 (Поэтика антологии "The Thackery T. Lambshead Cabinet of Curiosities"): 1 заявок
#   Проект 835 (Кураторы‑наставники: старт в университете): 2 заявок
#   Проект 840 (Исследователь): 1 заявок
#   Проект 848 (Межкультурная подготовка в детской образовательной среде): 1 заявок
#   Проект 852 (Продвижение бренда сумок и аксессуаров MOSSA в социальных сетях): 1 заявок
#   Проект 869 (Оценка несоответствия границ субъектов РФ «естественным» функциональным границам регионов: опыт экономического районирования): 1 заявок
#   Проект 871 (Малый историко-филологический факультет): 1 заявок
#   Проект 880 (Применение современных переводческих технологий в российских вузах): 1 заявок
#
# Распределение оценок:
#   Средняя оценка: 8.56
#   Медиана: 9.00
#   Мин/Макс: 5/10
#
# ✓ Визуализация сохранена в analysis_500_students.png
# ============================================================
# Генерация датасета для 1000 студентов
# ============================================================
# Генерация данных для 1000 студентов...
#   - Создание кластеров студентов...
#   - Генерация оценок студентов на основе кластеров...
#   - Генерация заявок...
#   - Данные сохранены в applications_1000_students.csv
# ✓ Сгенерировано 1990 заявок от 1000 студентов
#
# === Анализ данных ===
# Всего заявок: 1990
# Всего студентов: 1000
# Среднее количество заявок на студента: 1.99
#
# Распределение заявок по проектам:
#   Проект 1 (Исследование приоритетов и механизмов реализации отраслевых (секторальных) политик в избранных странах БРИКС (членах и кандидатах), во взаимосвязи с повесткой международных доноров): 272 заявок
#   Проект 2 (Антрополе - научно-популярный видео-подкаст о необычных социальных феноменах): 135 заявок
#   Проект 3 (Разработка, создание и ведение сайта, посвященного истории арабских студентов, выпускников художественных ВУЗов СССР (1950-е - 1991 г.)): 93 заявок
#   Проект 4 (Перевод с английского языка коллективной монографии «Пятьдесят ключевых мыслителей в криминологии» (науч. ред.: Кейт Хейворд, Шадд Маруна, Джейн Муни, изд-во Routledge, 2010. — 352 с.).): 60 заявок
#   Проект 5 (Сеть военно-политических союзов в Евразии: база данных): 44 заявок
#   Проект 6 (Дизайн учебных материалов (презентаций)): 43 заявок
#   Проект 7 (ОРЗ Изучении практик многоязычного обучения в школах Республики Бурятия): 32 заявок
#   Проект 8 (Привязанность к месту и психосоциальное здоровье: метаанализ): 42 заявок
#   Проект 9 (Подготовка управленческих решений на корпоративном уровне): 24 заявок
#   Проект 10 (Дизайн лонгрида "Корея в Москве и Санкт-Петербурге"): 28 заявок
#   Проект 11 (Копирайтер): 29 заявок
#   Проект 12 (Переводы пьес театра Кабуки с классического японского языка): 29 заявок
#   Проект 13 (Японская библиотека ИКВИА: организация и каталогизация): 21 заявок
#   Проект 14 (Ведение социальных сетей проекта про предпринимательство и стартапы): 20 заявок
#   Проект 15 (Корпус «Полевые материалы российско-вьетнамских лингвистических экспедиций»: создание лингвистического компонента): 20 заявок
#   Проект 16 (Правовые аспекты обучения моделей искусственного интеллекта: анализ зарубежного правового регулирования, судебной практики и саморегулирования): 20 заявок
#   Проект 17 (Работа со сложным гримом: шаржи и карикатуры, национально-исторический грим): 18 заявок
#   Проект 18 (Флипбук на JS): 15 заявок
#   Проект 19 (Создание электронной базы данных архива художника (на примере архивов В.Г. Вейсберга и Б.К. Касаткина). Часть2.): 17 заявок
#   Проект 20 (Исторические сферы влияния: создание базы данных): 14 заявок
#   Проект 21 (Ежемесячный мониторинг мировой экономики и геополитических рисков «GlobBaro HSE» (сентябрь-март 2026)): 16 заявок
#   Проект 22 (Просветительский проект «Голос Востока»): 11 заявок
#   Проект 23 (Анализ, описание и обработка электронных документов кадровых практик Всероссийского конкурса "Лучшие кадровые практики и инициативы в системе государственного и муниципального управления"): 12 заявок
#   Проект 24 (Перевод современной персидской художественной и мемуарной прозы): 8 заявок
#   Проект 25 (Лексика эфиопской Книги Юбилеев: составление глоссария ко второй главе): 16 заявок
#   Проект 26 (Развитие и продвижение студенческой научно-популярной организации «Восточный причал»): 10 заявок
#   Проект 27 (Перевод современной хиндиязычной прозы): 13 заявок
#   Проект 28 (Запуск регулярного подкаста НИУ ВШЭ о странах Азии): 8 заявок
#   Проект 29 («География» Страбона как историко-географический источник и античная география рубежа нашей эры.): 7 заявок
#   Проект 30 (Классический японский язык: чтение, перевод, анализ грамматики древних текстов): 11 заявок
#   Проект 31 (Студенческий клуб "Говорим об Эфиопии"): 9 заявок
#   Проект 32 (История турецкой литературы и фольклора): 6 заявок
#   Проект 33 (Медиапродвижение магистерской программы «Мусульманские миры в России (история и культура)»): 3 заявок
#   Проект 34 (Арабский рассказ и современная литературная теория): 9 заявок
#   Проект 35 (Египетский и сирийский диалекты арабского языка: создание учебного пособия): 10 заявок
#   Проект 36 (Проект по развитию центра культурной идентичности при факультете креативных индустрий ВШЭ): 5 заявок
#   Проект 37 (Правовая азбука для НКО Центр равных возможностей "Вверх" (проведение мастер-классов и разработка методических материалов), новый набор (третий год реализации проекта)): 9 заявок
#   Проект 38 (Евразийская интеграция: правовое измерение): 6 заявок
#   Проект 39 (Медиаосвещение спортивных событий ВШЭ. Развитие единого медиа канала по спорту в университете): 5 заявок
#   Проект 40 (Взгляд изнутри ВШБ НИУ ВШЭ): 4 заявок
#   Проект 41 (Учебный ассистент по дисциплине "Бизнес-анализ в цепях поставок"): 7 заявок
#   Проект 42 (Социальная память о философии и философах в документальном советском и перестроечном кино и современных медиа): 11 заявок
#   Проект 43 (Везувианская зона как метамузей Древнего Рима: апробация редизайна курса и подготовки учебного пособия): 6 заявок
#   Проект 44 (Меж- & транскультурная коммуникация и межкультурная компетенция/ Inter-&Transkulturalität und Interkulturelle Kompetenz (онлайн)): 6 заявок
#   Проект 45 (Проектирование хранилища данных для приюта для бездомных животных): 6 заявок
#   Проект 46 (Стартап: Цифровой маркетплейс недвижимости "Домдом"): 7 заявок
#   Проект 47 (Музыкальная культура России и Европы: Дон-Жуан в музыкальной культуре (опера, балет, мюзикл)): 13 заявок
#   Проект 48 (Медиакоманда ЭКСТРА): 3 заявок
#   Проект 49 (Разработка Телеграм-бота по подбору образовательных программ): 8 заявок
#   Проект 50 (Интермедиальные стратегии авангарда): 5 заявок
#   Проект 51 (Разработка периодического издания в сфере гуманитарных наук 2025-2026 уч.г. (10-й этап). Журнал молодых ученых «Метаморфозис». Том 10.): 5 заявок
#   Проект 52 (Юридическая клиника факультета права НИУ ВШЭ): 4 заявок
#   Проект 53 (Чтение древнееврейской прозы): 5 заявок
#   Проект 54 (Разговорный английский клуб НИУ ВШЭ СПб Talking Crows): 9 заявок
#   Проект 55 (Научно-популярный проект "Мультивселенная ученых"): 5 заявок
#   Проект 56 (Визовое сопровождение иностранных студентов): 4 заявок
#   Проект 57 (Особенности ведения бизнеса в разных странах 2025-2026): 6 заявок
#   Проект 58 (Разработка и развертывание стратегии международной компании 2025-2026): 4 заявок
#   Проект 59 (Управление проектами и процессами в международном бизнесе 2025-2026): 4 заявок
#   Проект 60 (Развитие Платформы соинвестирования ключевых компетенций (ПСКК) во взаимодействии с Минпромторгом России, Госкорпорациями "Ростех" и "Росатом" 2025-2026): 3 заявок
#   Проект 61 (Эволюция политической и деловой элиты в современной России): 8 заявок
#   Проект 62 (Визуальные объекты как исторический источник): 3 заявок
#   Проект 63 (Кинопроба. Медиа акселератор для НКО): 3 заявок
#   Проект 64 (Медиакоманда ЭКСТРА: для ОП «Журналистика» и «Медиакоммуникации»): 6 заявок
#   Проект 65 (Организационное сопровождение курса и педагогический дизайн его элементов): 7 заявок
#   Проект 66 (Межрегиональный научно-популярный фестиваль «Делай, что любишь!»): 4 заявок
#   Проект 67 (Волонтерство на XVI Международной конференции исследователей высшего образования (конференции ИВО)): 4 заявок
#   Проект 68 (Создание полноценного цифрового (или omnichannel) бизнес-проекта, готового к выходу на рынок): 1 заявок
#   Проект 69 (Ведение телеграм-канала центра российской истории и культуры при факультете креативных индустрий Высшей школы экономики): 8 заявок
#   Проект 70 (Проект по развитию центра российской истории и культуры при факультете креативных индустрий ВШЭ): 6 заявок
#   Проект 71 (Медиакоманда Центра Культур): 1 заявок
#   Проект 72 (Графический дизайнер для сообщества КИвО (2025)): 3 заявок
#   Проект 73 (Участие и создание креативных роликов на тему Ирана): 3 заявок
#   Проект 74 (Кейсбук: Социальное предпринимательство в России): 3 заявок
#   Проект 75 (Китайский клуб НИУ ВШЭ 2025/2026): 4 заявок
#   Проект 76 (Организация Школы юного востоковеда 2025/2026): 3 заявок
#   Проект 77 (Количественный анализ международной торговли): 3 заявок
#   Проект 78 (Международный мониторинг ответственного бизнеса): 3 заявок
#   Проект 79 (Съемки историй-секвенций): 3 заявок
#   Проект 80 (Предпринимательский класс: школа наставников): 3 заявок
#   Проект 81 (Съемки мини-секвенций для альманаха): 4 заявок
#   Проект 82 (Организация мероприятий культурно-просветительской направленности (клуб Наследие.ВШЭ)): 1 заявок
#   Проект 83 (Обработка материалов экспедиции "Общественная самоорганизация и система муниципального управления: теория взаимовлияния, опыт Челябинской области, пути повышения эффективности конструктивного взаимодействия"): 2 заявок
#   Проект 84 (Научные Кураторы НИУ ВШЭ: вовлечение иностранных студентов в научную деятельность): 2 заявок
#   Проект 85 (Ведение социальных сетей проекта «Научные кураторы НИУ ВШЭ»): 2 заявок
#   Проект 86 (Ведение телеграм-канала об академическом развитии и помощи в написании работ «Писать нельзя откладывать»): 7 заявок
#   Проект 87 (Школа будущего международника: десятый сезон (2025/2026)): 3 заявок
#   Проект 88 (Медиа-сопровождение и продвижение деятельности Центра бизнес-образования НИУ ВШЭ-Пермь.): 2 заявок
#   Проект 89 (Внешняя политика России в отношении стран Латинской Америки в XXI веке): 3 заявок
#   Проект 90 (Эволюция политики и стандартов интернет-контента: постсоветское пространство и глобальный контекст): 3 заявок
#   Проект 91 (Современные подходы к снижению коррупции в контрольной (надзорной) деятельности: российский и зарубежный опыт): 1 заявок
#   Проект 92 (Перспектива замены менеджеров среднего звена искусственным интеллектом): 3 заявок
#   Проект 93 (Кураторы общежития): 3 заявок
#   Проект 94 (Современные тренды государственного управления и их роль в противодействии коррупции): 2 заявок
#   Проект 95 (Антикоррупционные требования в частном секторе и защита компаний от коррупционных и правовых рисков: опыт зарубежных юрисдикций): 5 заявок
#   Проект 96 (Предупреждение коррупции в правоохранительных органах: международная стандарты и практика): 1 заявок
#   Проект 97 (Коррупционные практики в банкротных процедурах): 2 заявок
#   Проект 98 (Специализированные антикоррупционные органы – международные подходы и практика): 2 заявок
#   Проект 99 (Противодействие коррупции в контексте современных изменений публичной политики): 3 заявок
#   Проект 100 (Коррупционные риски в госсекторе в России и зарубежных странах): 4 заявок
#   Проект 101 (Создание и редактирование контента для студенческого интернет-портала Hitmedia.su): 6 заявок
#   Проект 102 (Ближневосточный клуб НИУ ВШЭ: платформа для изучения региона и развития академического и карьерного потенциала студентов-ближневосточников 2025/26): 2 заявок
#   Проект 103 (Разработка и редактирование информационного бюллетеня «СРЕДА» №9 (октябрь 2025 г.) и №10 (ноябрь 2025 г.)): 1 заявок
#   Проект 104 (Ведение авторского телеграмм-канала "В поисках равновесия"): 4 заявок
#   Проект 105 (Освещение игрового и тренировочного процесса Сборных команд НИУ ВШЭ (мужских и женских) по футболу, футзалу, пляжному футболу в медиа ресурсах. Репортажи, трансляции, статьи, аналитика. Осень 2025): 5 заявок
#   Проект 106 (Организация, проведение и освещение Кубка по футзалу среди студентов НИУ ВШЭ - 2025.): 5 заявок
#   Проект 107 (Консалтинг-проект в сфере юридического сопровождения творческих проектов студентов): 2 заявок
#   Проект 108 (Проблема универсального языка в англосаксонской философии середины — второй половины XVII в. (Дж.Уилкинс, Дж.Дальгарно) - 3.): 3 заявок
#   Проект 109 (Японский клуб «Мусуби» НИУ ВШЭ): 3 заявок
#   Проект 110 (Конфликт интересов в коммерческих организациях: проблемы теории и практики): 4 заявок
#   Проект 111 (“Пишу тебе”: цифровой корпус почтовых открыток. Часть 3): 3 заявок
#   Проект 112 (Практикум Совета молодых дипломатов): 3 заявок
#   Проект 113 (Антикоррупционные расследования в коммерческом секторе): 3 заявок
#   Проект 114 (Создание каталога нереализованных литературных журналов и газет XIX века): 2 заявок
#   Проект 115 (Религиозный ландшафт города: пост-секулярная история религиозных общин Санкт-Петербурга): 2 заявок
#   Проект 116 (Баскетбол в НИУ ВШЭ): 3 заявок
#   Проект 118 (Университетские кодексы и их влияние на этику поведения): 5 заявок
#   Проект 119 (SMM-сопровождение телеграм-СМИ о моде "кисс"): 2 заявок
#   Проект 120 (Продвижение в социальных сетях деятельности научно-учебной лаборатории исследований современного Ирана): 1 заявок
#   Проект 121 (Корпус русскоязычных газет XIX века. 2025-2026 учебный год): 2 заявок
#   Проект 122 (Сравнение современных проблем Восточной Азии через призму градиентов социально-экономического развития): 1 заявок
#   Проект 123 (Подготовка документов для поступления в магистратуру для выпускников бакалавриата Школы востоковедения НИУ ВШЭ): 4 заявок
#   Проект 124 (Консультация историка для киноклуба): 7 заявок
#   Проект 125 (Новости Ибероамерики-II): 6 заявок
#   Проект 126 (Поэзия жанра хайку как фактор конвергенции культур Востока и Запада): 4 заявок
#   Проект 127 (Редакция социальных сетей и сайта Института медиа НИУ ВШЭ (первое полугодие 2025-2026)): 3 заявок
#   Проект 128 (Помощь в организации и проведении 14й Международной научной конференции «Общественная самоорганизация, государственное управление и местное самоуправление в России и за рубежом»): 2 заявок
#   Проект 129 (Первый выход в поле: этнографические методы в социальной антропологии): 2 заявок
#   Проект 130 (Китайский Театр НИУ ВШЭ): 2 заявок
#   Проект 131 (Языки и тексты буддизма: перевод и исследование "Гимна в сто пятьдесят строф" Матричеты. 2025/26 учебный год): 1 заявок
#   Проект 132 (Анализ полевых данных и этика исследования): 1 заявок
#   Проект 133 (Социальная теория и этнография: 2025/2026): 2 заявок
#   Проект 134 (Хакатон "Применение искусственного интеллекта для решения задач рынка труда"): 2 заявок
#   Проект 135 (Языковое сопровождение 14-й Международной научной конференции «Общественная самоорганизация, государственное управление и местное самоуправление в России и за рубежом»): 3 заявок
#   Проект 136 (Подготовка чиновников по особым поручениям (по материалам XIX-XXI вв.): второй сезон): 1 заявок
#   Проект 137 (Школьное математическое образование первой четверти XXI века: аналитические материалы): 3 заявок
#   Проект 138 (Данные РМЭЗ в исследовании перехода от учебы к работе): 2 заявок
#   Проект 140 (Японский театр: погружение в культуру через игру): 3 заявок
#   Проект 141 (Организация освещения игр и соревнований спортивных сборных команд и спортивных студенческих организаций ВШЭ): 5 заявок
#   Проект 142 (Телеграм канал Департамента социологии НИУ ВШЭ СПб): 2 заявок
#   Проект 143 (Менторская поддержка участников Всероссийского кейс-чемпионата школьников по экономике и предпринимательству): 3 заявок
#   Проект 146 (Ассистенты Центра кинопроизводства Института кино, 2025-2026 учебный год): 4 заявок
#   Проект 147 (Организация выставки работ южнокорейского художника Пён Сичжи в Москве, посвященной столетию со дня его рождения): 1 заявок
#   Проект 148 (Организация митап-форумов в рамках Межкампусного проекта «Точка Сборки»): 1 заявок
#   Проект 149 (Работа с материалами фольклорных экспедиций 2025): 4 заявок
#   Проект 151 (Итальянский клуб ВШЭ): 2 заявок
#   Проект 152 (Психофизиологическое исследование: Как мотивация влияет на рабочую память?): 1 заявок
#   Проект 153 (Транскрибирование и редактура видеозаписей лекций А. С. Немзера): 2 заявок
#   Проект 154 (Многоязычие иранских СМИ): 4 заявок
#   Проект 155 (Музеи Ирана): 1 заявок
#   Проект 157 (Работа в проекте Школа предпринимательства: от трекеров и кураторов проектов до пиар-менеджеров и дизайнеров): 3 заявок
#   Проект 158 (Анализ метамотивационных оснований существования социальных групп): 1 заявок
#   Проект 159 (Исследование правового обеспечения информационной безопасности стран БРИКС): 1 заявок
#   Проект 160 (Доработка цифровой платформы «Инновационное управление» для учебных и исследовательских целей): 2 заявок
#   Проект 161 (Библиотека научно-образовательной секции исследований Ближнего Востока и Северной Африки Школы востоковедения («Ближневосточный кабинет»).): 1 заявок
#   Проект 162 (Подкаст об ответственном отношении к животным #НеЗвери. 4 сезон): 2 заявок
#   Проект 163 (Проект по юмористической импровизации "Обстоятельство"): 3 заявок
#   Проект 164 (Современное Искусство Ближнего Востока): 2 заявок
#   Проект 165 («Small-talk»: языковая помощь москвичам старшего возраста): 4 заявок
#   Проект 166 (Кураторы общежитии): 3 заявок
#   Проект 167 (Учебные ассистенты в Лицее НИУ ВШЭ): 3 заявок
#   Проект 168 («Подготовка и проведение Ежегодной Международной научной Конференции «Октябрьские чтения» 2025.»): 1 заявок
#   Проект 170 (Адаптация студентов первого курса): 1 заявок
#   Проект 171 (Перевод ключевых экокритических статей): 2 заявок
#   Проект 172 (Апробация шкалы межпоколенного конфликта на рабочем месте на русскоязычной выборке): 1 заявок
#   Проект 173 (Источниковедение и историография Кореи): 1 заявок
#   Проект 175 («Менторство в психологических исследованиях» - студенческий проект по сопровождению участников конкурса научно-исследовательских проектов «Высший пилотаж» 2025-2026): 1 заявок
#   Проект 176 (Digital Days на Факультете гуманитарных наук: сотрудничество гуманитарных и цифровых специалистов): 3 заявок
#   Проект 177 (Интервью с выпускниками ОП "Филология"): 2 заявок
# ...
#   Проект 717 (Юридическая клиника): 5 заявок
#   Проект 719 (Ассистент преподавателя (Общество и здоровье в исторической перспективе)): 1 заявок
#   Проект 720 (Ассистент преподавателя (Человечество, болезнь и здоровье в прошлом и настоящем)): 3 заявок
#   Проект 721 (Внедрение, поддержка и сопровождение информационной системы управления ИТ-инфраструктурой университета): 4 заявок
#   Проект 722 (Разработка информационной системы учёта материала из социальных сетей): 4 заявок
#   Проект 723 (Библиотека кейсов устойчивого развития): 4 заявок
#   Проект 724 (Die Deutsch-Experten: Эксперты по немецкому): 2 заявок
#   Проект 726 (Языковые универсалии и языковая идентичность социальных групп (региональная, профессиональная, поколенческая)): 2 заявок
#   Проект 727 (Школьный проект с Вышкой): 5 заявок
#   Проект 728 (Топография публичных пространств "Второй культуры" Ленинграда 1970–80-х): 1 заявок
#   Проект 729 (Авторская группа по написанию фабул игровых дел): 8 заявок
#   Проект 730 (Античная литература в историческом развитии): 4 заявок
#   Проект 731 (Прикладные исследования современного фольклора): 1 заявок
#   Проект 732 (Анализ предложения российского цифрового православного образования): 1 заявок
#   Проект 733 (Создание «Антикоррупционного симулятора» как инструмента антикоррупционного просвещения): 5 заявок
#   Проект 734 (Формирование государственной политики Китая по достижению технологического суверенитета в ответ на санкции США): 3 заявок
#   Проект 735 (Разработка и отладка учебно-методических материалов по дисциплинам «Профориентационный семинар» и «Проектный семинар» для студентов 1-го курса РИСБ): 3 заявок
#   Проект 736 (Проведение профориентационной школы "МИРЭК Junior"): 2 заявок
#   Проект 737 (Цифровой Ботанический сад: структуры, образы, контексты): 2 заявок
#   Проект 738 (Семантическое поле "мешать" в современном персидском (или таджикском) языке): 5 заявок
#   Проект 739 (Национализация рабочей силы ("Гульфизация")﻿: Сбор Данных и Нарративный Анализ): 4 заявок
#   Проект 740 (Работа в архиве РНБ): 3 заявок
#   Проект 741 (СНО "ФИЛОЛОГИЯ" НИУ ВШЭ-САНКТ-ПЕТЕРБУРГ): 2 заявок
#   Проект 742 (Малый факультет социальных наук: практика работы с целевой аудиторией, медиаосвещение событий факультета): 5 заявок
#   Проект 743 (тест): 1 заявок
#   Проект 744 (Продвижение и ведение социальных сетей проекта о российской музыке «БАЯН»): 2 заявок
#   Проект 745 (Художественный перевод с французского языка): 1 заявок
#   Проект 746 (Просоциальное поведение в условиях дошкольного образования. Как учатся жалеть, делиться, сотрудничать и помогать современные дети?): 2 заявок
#   Проект 747 (Древнееврейский язык: разработка учебных материалов): 2 заявок
#   Проект 748 (История общественно-политической жизни Санкт-Петербурга в 90-е годы): 2 заявок
#   Проект 749 (Разработка и проведение массовых молодёжных мероприятий в формате гражданского образования в сфере молодёжной политики): 7 заявок
#   Проект 750 (Вольная редакция ОП «Политология и мировая политика»): 1 заявок
#   Проект 751 (Разработка MVP для стартапа): 5 заявок
#   Проект 752 (Практики формирования и оценки развития речи: сравнение учебных упражнений и контрольных заданий в курсах русского языка для носителей и иностранцев): 2 заявок
#   Проект 753 (Мониторинг глобального бизнеса: страновые обзоры): 2 заявок
#   Проект 754 (Разработка социального международного сервиса для объединения пользователей и сейлеров): 4 заявок
#   Проект 755 (Разработка сводного отчета по статическому и композиционному анализам для оценки уровня безопасности разрабатываемого ППО): 3 заявок
#   Проект 756 (Киноклуб 21 век): 6 заявок
#   Проект 757 (Экспертная сессия: "Turning Creativity into Business" 2026): 6 заявок
#   Проект 758 (Программа поддержки и просвещения родителей. ДПО, ДО, КПК, тренинг): 3 заявок
#   Проект 759 (Проект Network for Asia Vision Initiative (NAVI)): 5 заявок
#   Проект 760 (Анализ курсов по цифровым инструментам и искусственному интеллекту в преподавании): 1 заявок
#   Проект 761 (Подготовка и проведение Восьмой международной конференции Модели ООН «Higher School of Economics International Model United Nations» – HSEIMUN 2026): 4 заявок
#   Проект 762 (Разработка MVP платформы для ИИ-персонализации подготовки к олимпиадам): 1 заявок
#   Проект 763 (Инхаус-юрист в FMCG секторе: практикум от Nestlé): 4 заявок
#   Проект 764 (Автоматическая редакция): 4 заявок
#   Проект 765 (Учебные Ассистенты 3-4 Модули 2025-2026 Академический Год. Бакалавры Кёнхи. Кредиты): 4 заявок
#   Проект 766 (Волонтёрство на XIII ежегодной международной конференции по мировой экономике “БРИКС и переосмысление глобального экономического порядка” (2025)): 7 заявок
#   Проект 767 (Создание Telegram-бота для поиска научных конференций и журналов «AkademGid» (Факультет креативных индустрий)): 3 заявок
#   Проект 768 (Разработка кадровой стратегии финансово-технологической компании): 2 заявок
#   Проект 769 (Разработка онлайн-платформы для продажи товаров ручной работы): 2 заявок
#   Проект 770 (Проектирование мобильного приложения CityScan AI – интеллектуального сканера уличных и общественных проблем): 5 заявок
#   Проект 771 (Организация конференции НУГ «(Не)официальные герои ленинградской “второй культуры”»): 2 заявок
#   Проект 772 (Менторы для иностранных слушателей центра русского языка и культуры): 4 заявок
#   Проект 773 (Совершенствование механизмов государственной социальной поддержки студентов: опыт стран БРИКС): 1 заявок
#   Проект 774 (Формирование ценностного предложения работодателя (EVP) с использованием смешанных методов исследования 2 волна): 2 заявок
#   Проект 775 (Правовое регулирование противодействия легализации (отмыванию) доходов, полученных преступным путем: международный и национальный уровень): 1 заявок
#   Проект 776 (Киноклуб в человекоцентрированном подходе): 2 заявок
#   Проект 777 (Ассистент преподавателя по дисциплине "Введение в количественный анализ текста"): 3 заявок
#   Проект 778 (Проектирование и разработка программного обеспечения для персонализированного подбора рецептов на платформе Android): 2 заявок
#   Проект 779 (Разработка Web-приложения для бронирования залов на языке Python с использованием фреймворка FastAPI и ReactJS): 1 заявок
#   Проект 780 (Проектирование и разработка кросс-платформенного приложения для управления личными финансами с backend на языке Java): 1 заявок
#   Проект 781 (Проектирование и разработка мобильного приложения на платформе Android для отслеживания приёма лекарств с целью личного использования): 2 заявок
#   Проект 782 (Проектирование мобильного приложения для фитнеса и оплаты услуг фитнес-тренера на языке Java с использованием фреймвока React Native): 2 заявок
#   Проект 783 (Разработка мобильного приложения на платформе Android для мониторинга и улучшения ментального здоровья на языке Kotlin): 2 заявок
#   Проект 784 (Проектирование архитектуры мобильного приложения геолокационной социальной сети с использованием фреймворка Flutter): 2 заявок
#   Проект 785 (Разработка мобильного приложения для публикации авторами книг или историй с монетизацией без участия издателя с использованием фреймворка React Native): 5 заявок
#   Проект 786 (Разработка кроссплатформенного приложения «StudentDiscount» для управления личными скидками студентов): 3 заявок
#   Проект 787 (Разработка кроссплатформенного приложения для владельцев гражданского оружия на Rust и фреймворке Dioxus): 5 заявок
#   Проект 789 (Разработка стратегии продвижения инновационного продукта компании Endokey): 1 заявок
#   Проект 790 (Школьный буллинг как фактор подавления агентности: анализ механизмов и поиск противодействий): 1 заявок
#   Проект 791 (Поколение Альфа: новая парадигма агентности в цифровую эпоху): 2 заявок
#   Проект 792 (Влияние семейного контекста на формирование агентности у детей и подростков): 3 заявок
#   Проект 793 (Чтение арабских текстов): 1 заявок
#   Проект 795 (Сон Журавля): 1 заявок
#   Проект 796 (Международные амбассадоры НИУ ВШЭ – Санкт-Петербург): 3 заявок
#   Проект 797 (Медиацентр Дирекции по работе с молодёжью за рубежом): 4 заявок
#   Проект 798 (Персидский язык для кросс-культурных исследований и анализа политической динамики в странах Ирана и региона): 3 заявок
#   Проект 799 (Разработка учебного пособия "Сборник нормативно-правовых актов СССР"): 3 заявок
#   Проект 800 (PsyVerse: медиа департамента психологии): 5 заявок
#   Проект 801 (Автоматизация регулярного отчета для отдела e-commerce на базе PowerBI): 1 заявок
#   Проект 802 (Мировая и российская практики бюджетирования бизнеса): 5 заявок
#   Проект 803 (Создание управленческо-правовой интерактивной карты "Старт предпринимателя в системе публичных закупок): 4 заявок
#   Проект 805 (Разработка продвинутой интерактивной платформы с внедренным искусственным интеллектом для изучения Китайского языка для студентов 1-4 курсов.): 4 заявок
#   Проект 806 (Создание образовательного Vk-бота "Hanyu for everyone collection" как медиа-сборника материалов для изучения китайского языка на всех уровнях HSK): 5 заявок
#   Проект 807 (Интерактивная карта цифровых решений системы публичных закупок с тренажером действий заказчиков и участников закупок): 3 заявок
#   Проект 809 (База российских публикаций): 4 заявок
#   Проект 810 (Трансформация доказательственной деятельности в уголовном судопроизводстве: вызовы информационного общества): 1 заявок
#   Проект 811 (Исследование пользовательского опыта. Проведение глубинных интервью пользователей ДПО.): 3 заявок
#   Проект 812 («Говори на языке бабушки»: SMM и создание контента телеграм-канала): 5 заявок
#   Проект 813 (Подготовка материалов и ведение Telegram-канала кафедры финансового менеджмента в государственном секторе): 2 заявок
#   Проект 814 (Арт-туры по Санкт-Петербургу для приложения): 1 заявок
#   Проект 815 (Продвижение локального бренда парфюмерии): 3 заявок
#   Проект 816 (Консалтинговый проект в рамках экспедиции в Смоленскую область "Вспышка памяти"): 1 заявок
#   Проект 818 (Подготовка Рейтинга инновационной привлекательности мировых городов HSE GCII 2026): 2 заявок
#   Проект 819 (Сравнение методов корректировки распределения доходов домашних хозяйств, основанных на распределении Парето): 1 заявок
#   Проект 820 (Статистический анализ склонности к сбережению домашних хозяйств на примере развивающихся стран): 3 заявок
#   Проект 821 (Платформа карьерного роста): 3 заявок
#   Проект 822 (Организация продвижения, распространения и популяризации юридической науки среди молодых специалистов: исследование лучших практик): 3 заявок
#   Проект 823 (Аналитика бизнес-данных для обоснования принятия решения (<…указать тип или отраслевую принадлежность компании…>).): 3 заявок
#   Проект 824 (Перспективы взаимоотношений России и европейских стран в 2025-2035 гг.): 1 заявок
#   Проект 825 (Театр на французском языке): 3 заявок
#   Проект 826 (Разработка системы распределения затрат при совместных расходах): 2 заявок
#   Проект 827 (Разработка и проведение кампании по продвижению образовательной программы НИУ ВШЭ в соцсетях): 3 заявок
#   Проект 828 (Единое информированное добровольное согласие и анкета донора крови и (или) её компонентов): 3 заявок
#   Проект 829 (Социально-психологическая поддержка peer-to-peer): 3 заявок
#   Проект 830 (Поэтика антологии "The Thackery T. Lambshead Cabinet of Curiosities"): 3 заявок
#   Проект 831 (Философия брака в работах В. В. Розанова): 2 заявок
#   Проект 832 (Сбор и обработка языкового материала для корпусного анализа): 4 заявок
#   Проект 833 (Инициативные проекты студентов ОП "Юриспруденция: цифровой юрист" (2025/2026 уч. год.)): 1 заявок
#   Проект 834 (Исследование восприятия эмоций): 3 заявок
#   Проект 835 (Кураторы‑наставники: старт в университете): 2 заявок
#   Проект 836 (Администрирование консультативной деятельности студентов 2 года обучения): 1 заявок
#   Проект 837 (Создание методик исследования семейной системы: взгляд изнутри): 1 заявок
#   Проект 838 («Доказательный анализ и отбор педагогических и управленческих практик, наиболее релевантных для арктического контекста г. Норильска»): 2 заявок
#   Проект 839 (Россия и страны Южной, Восточной и Юго-Восточной Азии: история отношений): 1 заявок
#   Проект 840 (Исследователь): 2 заявок
#   Проект 842 (Исследования в сфере поведенческой и экспериментальной экономики): 2 заявок
#   Проект 843 (Изучение использования русских модальных операторов «можно/мочь, нужно/должен» носителями русского языка в письменной речи): 2 заявок
#   Проект 844 (SMM менеджмент Банковского института): 2 заявок
#   Проект 845 (Влияние немедленной и отсроченной обратной связи на консолидацию кратковременной памяти в игровом обучении): 3 заявок
#   Проект 846 (Инклюзивная карьерная платформа Есть Дело): 5 заявок
#   Проект 847 (Шоу "Неро-баттлы"): 3 заявок
#   Проект 849 (Особенности политики Королевства Саудовская Аравия в отношении Исламской Республики Ирана в 2010-2025 гг.): 3 заявок
#   Проект 850 (Современные исследования психологии личности): 2 заявок
#   Проект 851 (Медиа развитие бренда технологичной спортивной одежды BOVKK): 3 заявок
#   Проект 852 (Продвижение бренда сумок и аксессуаров MOSSA в социальных сетях): 4 заявок
#   Проект 853 (Разработка маркетинговой стратегии для государственного литературного музея "XX век"): 1 заявок
#   Проект 854 (Сетевой анализ публикаций по тематике Государственное управление): 3 заявок
#   Проект 855 (Подбор и анализ телеграм-блогеров для выстраивания коллаборационной стратегии бренда): 2 заявок
#   Проект 856 (Стратагемность во внутренней и внешней политике Китая): 2 заявок
#   Проект 857 (Разработка и отладка учебно-методических материалов по дисциплине «Обеспечение качества и тестирование» для студентов 3-го курса программной инженерии): 1 заявок
#   Проект 858 (Драматургический подход к анализу рабочих дилемм сотрудников социальной сферы (на примере учителей)): 7 заявок
#   Проект 859 (Помощник преподавателя по дисциплине "Научно-исследовательский семинар" (4 курс)): 3 заявок
#   Проект 860 (Разработка веб-сайта на конструкторе веб-сайтов для размещения обучающих материалов для изучающих русский язык как иностранный и его наполнение): 1 заявок
#   Проект 861 (Оценка решений кейсов по правовой и финансовой грамотности): 4 заявок
#   Проект 862 (Подготовка к Олимпиаде по истории государства и права России и зарубежных стран): 4 заявок
#   Проект 863 (Научно-исследовательский семинар "Теория и практика международных и региональных исследований"): 2 заявок
#   Проект 865 (Базовый курс Малайско-индонезийского языка): 1 заявок
#   Проект 866 (Диагностика посттравматического роста): 3 заявок
#   Проект 867 (Ведение официального сайта ридинг-семинара «Метаэтика и моральная психология»): 2 заявок
#   Проект 869 (Оценка несоответствия границ субъектов РФ «естественным» функциональным границам регионов: опыт экономического районирования): 1 заявок
#   Проект 870 (Исследование архитектур, свойств и различных характеристик при построении беспроводной сети между микроконтроллерами ESP32 по принципу приемник-передатчик с помощью существующих радио средств.): 3 заявок
#   Проект 871 (Малый историко-филологический факультет): 3 заявок
#   Проект 872 (Расшифровка полевых данных арктических исследований): 5 заявок
#   Проект 873 (Воплощение образа Мии в сцене фильма "Ла-Ла Ленд"): 3 заявок
#   Проект 874 (Телефонный опрос организаций в рамках проектов Центра внутреннего мониторинга НИУ ВШЭ): 1 заявок
#   Проект 875 (Кибербезопасность детей и подростков): 6 заявок
#   Проект 876 (Разработка чат-бота для помощи людям с расстройствами пищевого поведения): 5 заявок
#   Проект 877 (Создание страницы (лендинга) проектов ПУЛ "Развитие университетов"): 2 заявок
#   Проект 878 (Разработка стратегической и контентно-коммуникационной системы продвижения экосистемы «Вулканариум–Ойкумена» в Telegram, VK и Email-каналах.): 3 заявок
#   Проект 879 (Обзор Методологии в Области Регионоведения. Этап сбора данных 1.): 6 заявок
#   Проект 880 (Применение современных переводческих технологий в российских вузах): 2 заявок
#
# Распределение оценок:
#   Средняя оценка: 8.40
#   Медиана: 9.00
#   Мин/Макс: 5/10
#
# ✓ Визуализация сохранена в analysis_7000_students.png
# ============================================================
# ✓ Все датасеты успешно сгенерированы!
# ============================================================

# %% [markdown]
# ## 8. Просмотр примеров данных

# %%
# Просмотрим первые несколько заявок из датасета с 500 студентами
print("Примеры заявок (первые 10 строк):")
display(results[500][0].head(10))

print("\nОписательная статистика по оценкам:")
display(results[500][0][['grade_1', 'grade_2', 'grade_3']].describe())

print("\nПроверка: заявки одного студента")
sample_student = results[500][0]['student_id'].iloc[0]
student_applications = results[500][0][results[500][0]['student_id'] == sample_student]
display(student_applications)
# Out:
# Примеры заявок (первые 10 строк):
#    application_id  student_id  project_id           timestamp
# 0               0           0          27 2024-09-06 07:14:00  \
# 1               1           0          15 2024-09-12 23:57:00
# 2               2           0           1 2024-09-08 01:01:00
# 3               3           1         131 2024-09-11 00:35:00
# 4               4           2           1 2024-09-10 13:14:00
# 5               5           3           2 2024-09-15 00:48:00
# 6               6           3           1 2024-09-08 10:17:00
# 7               7           4           1 2024-09-03 02:24:00
# 8               8           5          73 2024-09-11 08:51:00
# 9               9           6           4 2024-09-03 12:05:00
#
#                                    subject_1  grade_1
# 0                           Линейная алгебра        7  \
# 1                             Web-разработка        9
# 2                        Облачные вычисления        9
# 3                                Базы данных        9
# 4                                Компиляторы        8
# 5                     Распределенные системы       10
# 6  Объектно-ориентированное программирование       10
# 7                    Программирование на C++        8
# 8                          Теория вычислений        9
# 9                          Agile методологии        8
#
#                          subject_2  grade_2
# 0            Дискретная математика        8  \
# 1  Функциональное программирование        8
# 2                 Линейная алгебра        7
# 3    Параллельное программирование        8
# 4             Мобильная разработка        9
# 5        Математическая статистика        7
# 6                 Линейная алгебра        6
# 7                  Тестирование ПО        8
# 8    Параллельное программирование        8
# 9                    Анализ данных        9
#
#                                    subject_3  grade_3  days_since_start
# 0            Функциональное программирование        8                 5
# 1                           Линейная алгебра        7                11
# 2                       Мобильная разработка        8                 7
# 3                        Компьютерное зрение        9                10
# 4              Параллельное программирование        9                 9
# 5  Объектно-ориентированное программирование       10                14
# 6                             Разработка игр        8                 7
# 7                          Машинное обучение        9                 2
# 8                             Биоинформатика        8                10
# 9                Информационная безопасность        9                 2
# Описательная статистика по оценкам:
#           grade_1     grade_2     grade_3
# count  989.000000  989.000000  989.000000
# mean     8.561173    8.533873    8.571284
# std      1.134457    1.117633    1.094809
# min      5.000000    5.000000    5.000000
# 25%      8.000000    8.000000    8.000000
# 50%      9.000000    9.000000    9.000000
# 75%      9.000000    9.000000    9.000000
# max     10.000000   10.000000   10.000000
# Проверка: заявки одного студента
#    application_id  student_id  project_id           timestamp
# 0               0           0          27 2024-09-06 07:14:00  \
# 1               1           0          15 2024-09-12 23:57:00
# 2               2           0           1 2024-09-08 01:01:00
#
#              subject_1  grade_1                        subject_2  grade_2
# 0     Линейная алгебра        7            Дискретная математика        8  \
# 1       Web-разработка        9  Функциональное программирование        8
# 2  Облачные вычисления        9                 Линейная алгебра        7
#
#                          subject_3  grade_3  days_since_start
# 0  Функциональное программирование        8                 5
# 1                 Линейная алгебра        7                11
# 2             Мобильная разработка        8                 7

# %% [markdown]
# ## 9. Экспериментирование с параметрами

# %%
# Можно экспериментировать с разными значениями alpha
# alpha = 0.1 - кластеры далеко друг от друга (слабое перемешивание)
# alpha = 0.5 - кластеры близко (сильное перемешивание)
# alpha = 0.9 - кластеры очень близко (очень сильное перемешивание)

def experiment_with_alpha(n_students: int = 500):
    """
    Эксперимент с разными значениями alpha для наглядности.
    """
    alphas = [0.1, 0.3, 0.5, 0.7, 0.9]
    
    fig, axes = plt.subplots(1, len(alphas), figsize=(20, 4))
    
    for idx, alpha in enumerate(alphas):
        # Генерируем данные
        _, metadata = generate_synthetic_data(
            n_students=n_students,
            alpha=alpha,
            n_clusters=5,
            save_to_file=False
        )
        
        # Визуализация кластеров
        from sklearn.decomposition import PCA
        pca = PCA(n_components=2)
        features_2d = pca.fit_transform(metadata['student_features'])
        
        axes[idx].scatter(features_2d[:, 0], 
                         features_2d[:, 1],
                         c=metadata['cluster_labels'],
                         cmap='viridis',
                         alpha=0.6)
        axes[idx].set_title(f'α = {alpha}')
        axes[idx].set_xlabel('PC1')
        axes[idx].set_ylabel('PC2')
    
    plt.suptitle('Влияние параметра α на перемешивание кластеров', fontsize=14)
    plt.tight_layout()
    plt.savefig('alpha_experiment.png', dpi=300, bbox_inches='tight')
    print("✓ Результаты эксперимента сохранены в alpha_experiment.png")
    plt.show()

# Раскомментируйте для запуска эксперимента
# experiment_with_alpha(500)

# %% [markdown]
# ## 10. Экспорт итоговой статистики

# %%
# Создаем сводную таблицу по всем датасетам
summary_data = []

for n_students in dataset_sizes:
    apps_df, meta = results[n_students]
    
    all_grades = []
    for col in ['grade_1', 'grade_2', 'grade_3']:
        all_grades.extend(apps_df[col].dropna().values)
    
    summary_data.append({
        'Количество студентов': n_students,
        'Количество заявок': len(apps_df),
        'Заявок на студента': len(apps_df) / n_students,
        'Средняя оценка': np.mean(all_grades),
        'Медиана оценки': np.median(all_grades),
        'Кластеров': meta['n_clusters'],
        'Параметр α': meta['alpha']
    })

summary_df = pd.DataFrame(summary_data)
summary_df.to_csv('summary_statistics.csv', index=False, encoding='utf-8')

print("\nИтоговая статистика по всем датасетам:")
display(summary_df)
print("\n✓ Сводная статистика сохранена в summary_statistics.csv")
# Out:
# Итоговая статистика по всем датасетам:
#    Количество студентов  Количество заявок  Заявок на студента
# 0                   500                989            1.978000  \
# 1                  1000               1990            1.990000
# 2                  3000               6011            2.003667
# 3                  7000              14023            2.003286
#
#    Средняя оценка  Медиана оценки  Кластеров  Параметр α
# 0        8.555443             9.0          5         0.3
# 1        8.526131             9.0          5         0.3
# 2        8.415682             9.0          5         0.3
# 3        8.399748             9.0          5         0.3
# ✓ Сводная статистика сохранена в summary_statistics.csv
